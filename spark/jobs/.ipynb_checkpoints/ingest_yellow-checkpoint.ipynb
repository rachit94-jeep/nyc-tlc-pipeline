# %% [markdown]
# #### Ingesting Yellow Taxi Trip Data - April 2026

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.master('local[8]').\
                appName('Yellow Taxi Data Ingestion')\
                    .getOrCreate()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 3
#       1 spark = SparkSession.builder.master('local[8]').\
#       2                 appName('Yellow Taxi Data Ingestion')\
# ----> 3                     .getOrCreate()
#
# File c:\Users\I536982\Documents\Project Repository\NYC_TLC_PIPELINE\.venv\Lib\site-packages\pyspark\sql\session.py:559, in SparkSession.Builder.getOrCreate(self)
#     557     sparkConf.set(key, value)
#     558 # This SparkContext may be an existing one.
# --> 559 sc = SparkContext.getOrCreate(sparkConf)
#     560 # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     561 # by all sessions.
#     562 session = SparkSession(sc, options=self._options)
#
# File c:\Users\I536982\Documents\Project Repository\NYC_TLC_PIPELINE\.venv\Lib\site-packages\pyspark\core\context.py:542, in SparkContext.getOrCreate(cls, conf)
# ...
